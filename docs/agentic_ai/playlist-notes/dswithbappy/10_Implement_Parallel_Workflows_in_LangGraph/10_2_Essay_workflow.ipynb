# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from typing import TypedDict, Annotated
from pydantic import BaseModel, Field
import operator

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI(model_name="gpt-5-nano",  
 temperature=0.7)

# %%
class EvaluationSchema(BaseModel):

    feedback: str = Field(description='Detailed feedback for the essay')
    score: int = Field(description='Score out of 10', ge=0, le=10)

# %%
structured_model = model.with_structured_output(EvaluationSchema)

# %%
essay = """Europe in the Age of AI: The Regulatory Superpower

As the world rushes headlong into the era of artificial intelligence, the European Union finds itself playing a unique and complex role. While the United States and China dominate the race to build the largest foundation models and hardware ecosystems, Europe has positioned itself as the global conscience of the AI age. For Europe, the challenge is not simply about technological supremacy, but about ensuring that AI aligns with democratic values, human rights, and environmental sustainability.

Europe's strengths lie in its deep academic traditions and its commitment to ethical frameworks. The continent is home to world-class research hubs, producing some of the leading minds in machine learning. Furthermore, Europe has a distinct advantage in industrial and B2B AI, driven by its manufacturing powerhouses in Germany, France, and Scandinavia. However, Europe’s most defining characteristic in this era is its regulatory muscle. With the passage of the AI Act, the EU has created the world’s first comprehensive legal framework for artificial intelligence, categorizing systems by risk and demanding unprecedented transparency from tech companies.

The European vision for AI is heavily focused on public good and sustainability. There is a strong push toward "Green AI," ensuring that the massive energy consumption of data centers aligns with the continent's aggressive climate goals. In healthcare, European nations are leveraging AI to advance precision medicine and streamline public health systems, while fiercely protecting patient data. Additionally, significant investments are being made to develop open-source, multilingual AI models that preserve Europe's rich linguistic diversity and reduce reliance on Silicon Valley.

Despite these noble ambitions, Europe faces substantial hurdles. The continent suffers from a severe lack of hyperscale tech companies and domestic cloud infrastructure, leaving it heavily dependent on foreign technology. This "compute deficit" is compounded by a fragmented venture capital market, which often struggles to commercialize academic breakthroughs. Consequently, Europe frequently experiences a brain drain, as its brightest AI researchers are lured away by the massive salaries and computing resources offered by American and Chinese tech giants.

The central tension for Europe is whether its regulatory approach will foster "trustworthy AI" or stifle homegrown innovation. Critics argue that stringent compliance burdens will price European startups out of the market, relegating the continent to being a consumer of foreign AI rather than a creator. Proponents, however, believe that by setting global ethical standards—the "Brussels Effect"—Europe will ultimately attract users and enterprises that demand secure, unbiased, and privacy-respecting technologies.

To succeed, Europe must balance its protective instincts with aggressive investment in digital infrastructure and innovation. It needs to foster a unified digital single market that allows startups to scale across borders effortlessly, while also forging strategic alliances to secure supply chains for critical hardware like semiconductors.

In conclusion, Europe in the age of AI represents a profound geopolitical experiment. It is testing whether a society can successfully govern exponential technology without sacrificing economic competitiveness. If Europe succeeds, it will provide a desperately needed global blueprint for human-centric AI; if it fails, it risks becoming an over-regulated museum in a world driven by algorithmic innovation."""

# %%
print(structured_model)
# Out:
# first=_ChatModelBinding(bound=ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.4.8', 'langchain-openai': '1.3.3'}}, output_version=None, profile={'name': 'GPT-5 Nano', 'release_date': '2025-08-07', 'last_updated': '2025-08-07', 'open_weights': False, 'max_input_tokens': 272000, 'max_output_tokens': 128000, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': False, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True, 'tool_call_streaming': True}, client=<openai.resources.chat.completions.completions.Completions object at 0x1154f2cd0>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x11664d4d0>, root_client=<openai.OpenAI object at 0x1154f25d0>, root_async_client=<openai.AsyncOpenAI object at 0x11664d050>, model_name='gpt-5-nano', model_kwargs={}, openai_api_key=SecretStr('**********'), openai_proxy=None, stream_usage=True, stream_chunk_timeout=120.0), kwargs={'response_format': <class '__main__.EvaluationSchema'>, 'ls_structured_output_format': {'kwargs': {'method': 'json_schema', 'strict': None}, 'schema': {'type': 'function', 'function': {'name': 'EvaluationSchema', 'description': '', 'parameters': {'properties': {'feedback': {'description': 'Detailed feedback for the essay', 'type': 'string'}, 'score': {'description': 'Score out of 10', 'maximum': 10, 'minimum': 0, 'type': 'integer'}}, 'required': ['feedback', 'score'], 'type': 'object'}}}}}, config={}, config_factories=[]) middle=[] last=RunnableBinding(bound=RunnableLambda(...), kwargs={}, config={}, config_factories=[], custom_output_type=<class '__main__.EvaluationSchema'>)

# %%
prompt = f'Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10 \n {essay}'
result = structured_model.invoke(prompt)

# %%
result
# Out:
# EvaluationSchema(feedback='Strong overall language quality. The essay presents a clear thesis and maintains a consistent, formal policy-writing register throughout. It uses precise terminology (foundation models, regulatory muscle, Brussels Effect, Green AI) and blends descriptive analysis with evaluative stance in a cohesive argument. Readability is good: ideas unfold logically, and the prose gains momentum from well-chosen phrases like global conscience of the AI age and a regulatory blueprint for human-centric AI. The piece also balances aspiration with caution by acknowledging hurdles, which strengthens credibility.\n\nSuggestions for refinement:\n- Sentence length and rhythm: a few sentences are long and could be split to improve readability and emphasis. Varying sentence length can enhance cadence and retention.\n- Terminology and clarity: consider rewording some terms for broader clarity (for example, replace industrial and B2B AI with enterprise or industrial AI) and ensure regional terms are precise (Scandinavia vs Nordic countries) to avoid potential ambiguity.\n- Stylistic consistency: ensure consistent punctuation and quotation usage. If you quote terms like Green AI or the Brussels Effect, keeping a uniform style (e.g., without excessive quotation marks) helps readability.\n- Tone and nuance: while the piece presents a balanced view, a few assertions are strong (e.g., world’s first comprehensive legal framework for AI). Adding cautious qualifiers or brief caveats can improve nuance and reduce perceived absolutism.\n- Support and specificity: the argument benefits from concrete data or examples (even in policy prose) to ground claims about investment levels, regulatory impact, or brain drain. If this is intended as a policy brief, consider anchoring statements with a figure or citation.\n- Structural transitions: while the overall flow is good, introducing tighter topic sentences at the start of each paragraph can further guide the reader and strengthen the argumentative thread.\n- Closing impact: the conclusion is thought-provoking but could sharpen its takeaway with a more explicit policy implication or call to action.\n\nSample micro-edits (style ideas):\n- Replace a long opening clause with: For Europe, the challenge is not technological supremacy alone but ensuring AI aligns with democratic values, human rights, and sustainability.\n- Adjust regional reference: Germany, France, and the Nordic countries (instead of Scandinavia) to be geographically precise.\n- Streamline a sentence: Develop open-source, multilingual AI models that preserve Europe’s linguistic diversity and reduce reliance on Silicon Valley.\n\nOverall score: 8/10. The essay is compelling and well-written, with room for readability tweaks and a bit more precision and nuance in a few spots.', score=8)

# %%
class EssayState(TypedDict):

    essay: str
    language_feedback: str
    analysis_feedback: str
    clarity_feedback: str
    overall_feedback: str
    individual_scores: Annotated[list[int], operator.add]
    avg_score: float

# %%
def evaluate_language(state: EssayState):

    prompt = f'Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output = structured_model.invoke(prompt)

    return {'language_feedback': output.feedback, 'individual_scores': [output.score]}

# %%
def evaluate_analysis(state: EssayState):

    prompt = f'Evaluate the depth of analysis of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output = structured_model.invoke(prompt)

    return {'analysis_feedback': output.feedback, 'individual_scores': [output.score]}

# %%
def evaluate_thought(state: EssayState):

    prompt = f'Evaluate the clarity of thought of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output = structured_model.invoke(prompt)

    return {'clarity_feedback': output.feedback, 'individual_scores': [output.score]}

# %%
def final_evaluation(state: EssayState):

    # summary feedback
    prompt = f'Based on the following feedbacks create a summarized feedback \n language feedback - {state["language_feedback"]} \n depth of analysis feedback - {state["analysis_feedback"]} \n clarity of thought feedback - {state["clarity_feedback"]}'
    overall_feedback = model.invoke(prompt).content

    # avg calculate
    avg_score = sum(state['individual_scores'])/len(state['individual_scores'])

    return {'overall_feedback': overall_feedback, 'avg_score': avg_score}

# %%
graph = StateGraph(EssayState)

# add nodes
graph.add_node('evaluate_language', evaluate_language)
graph.add_node('evaluate_analysis', evaluate_analysis)
graph.add_node('evaluate_thought', evaluate_thought)
graph.add_node('final_evaluation', final_evaluation)

# add edges
graph.add_edge(START, 'evaluate_language')
graph.add_edge(START, 'evaluate_analysis')
graph.add_edge(START, 'evaluate_thought')


graph.add_edge('evaluate_language', 'final_evaluation')
graph.add_edge('evaluate_analysis', 'final_evaluation')
graph.add_edge('evaluate_thought', 'final_evaluation')

graph.add_edge('final_evaluation', END)

workflow = graph.compile()

# %%
workflow

# %%
essay2 = """The United States in the Age of AI: The Infrastructure and Capital Superpower

As the world navigates the maturing landscape of artificial intelligence in 2026, the United States stands as the undisputed epicenter of the AI revolution. Driven by an ecosystem of hyperscalers, massive venture capital, and a fiercely competitive free market, the US has transitioned AI from a phase of speculative experimentation into the fundamental backbone of its digital and physical economy. However, the American approach to AI is no longer just a story of software and algorithms; it has evolved into the most capital-intensive infrastructure buildout in modern history, testing the physical limits of the nation's energy grid and resources.

The defining characteristic of the US AI strategy is its sheer scale and rapid commercialization. Silicon Valley and major tech hubs have pioneered the shift toward "Agentic AI" and "Physical AI." Intelligence is no longer confined to chatbots on a screen; autonomous agents are now orchestrating complex, end-to-end enterprise workflows, while advanced robotics powered by massive neural networks are redefining logistics and manufacturing floors. For American corporations, the current era marks a structural reorganization where operating models are being fundamentally redesigned around human-machine collaboration rather than merely automating legacy processes.

Yet, this relentless pursuit of scale has collided with physical reality, triggering an unprecedented energy reckoning. The US is building massive AI data center clusters that require gigawatts of continuous power. With data center electricity consumption projected to more than double in a span of just a few years, the nation is facing a severe power bottleneck. Connecting to the traditional grid now takes years, prompting hyperscalers to pioneer a "Bring Your Own Power" (BYOP) movement. Tech giants are directly funding behind-the-meter gas generation, reviving dormant nuclear facilities, and investing in advanced cooling technologies to fuel their server farms. AI infrastructure has become such a critical priority that it is increasingly viewed through the lens of national security, prompting aggressive federal action to expand the domestic supply of key electrical grid components.

On the policy front, the US government has dramatically accelerated its embrace of artificial intelligence. Moving away from more cautious regulatory frameworks, the focus has shifted entirely to removing barriers to innovation and ensuring tech sovereignty. The goal is clear: maintain a decisive strategic edge over global competitors, particularly China. Federal AI spending has skyrocketed into the tens of billions, dominated overwhelmingly by the Department of Defense, which views AI supremacy as a non-negotiable imperative for future military readiness, cybersecurity, and global diplomacy.

However, this hyper-accelerated growth is not without domestic friction. At the local level, the proliferation of massive data centers is creating tension in communities grappling with the environmental footprint of these facilities. Concerns over local electricity rate hikes, immense water usage in water-stressed regions, and the strain on existing utilities highlight the localized costs of a global tech race. Furthermore, while the US excels at rapid technological deployment, the corporate sector is experiencing a deep divide between companies effectively restructuring for an AI-native future and those struggling with high failure rates due to poor data quality and broken processes.

In conclusion, the United States in the age of AI represents a high-stakes, capital-fueled engine of exponential growth. It is a nation betting that its unmatched capacity for private investment, hardware innovation, and sheer ambition can overcome formidable physical bottlenecks. The American trajectory will ultimately determine whether a market-driven society can build and sustain the colossal physical infrastructure required to unlock the next frontier of human intelligence."""

# %%
intial_state = {
    'essay': essay2
}

result = workflow.invoke(intial_state)

# %%
result
# Out:
# {'essay': 'The United States in the Age of AI: The Infrastructure and Capital Superpower\n\nAs the world navigates the maturing landscape of artificial intelligence in 2026, the United States stands as the undisputed epicenter of the AI revolution. Driven by an ecosystem of hyperscalers, massive venture capital, and a fiercely competitive free market, the US has transitioned AI from a phase of speculative experimentation into the fundamental backbone of its digital and physical economy. However, the American approach to AI is no longer just a story of software and algorithms; it has evolved into the most capital-intensive infrastructure buildout in modern history, testing the physical limits of the nation\'s energy grid and resources.\n\nThe defining characteristic of the US AI strategy is its sheer scale and rapid commercialization. Silicon Valley and major tech hubs have pioneered the shift toward "Agentic AI" and "Physical AI." Intelligence is no longer confined to chatbots on a screen; autonomous agents are now orchestrating complex, end-to-end enterprise workflows, while advanced robotics powered by massive neural networks are redefining logistics and manufacturing floors. For American corporations, the current era marks a structural reorganization where operating models are being fundamentally redesigned around human-machine collaboration rather than merely automating legacy processes.\n\nYet, this relentless pursuit of scale has collided with physical reality, triggering an unprecedented energy reckoning. The US is building massive AI data center clusters that require gigawatts of continuous power. With data center electricity consumption projected to more than double in a span of just a few years, the nation is facing a severe power bottleneck. Connecting to the traditional grid now takes years, prompting hyperscalers to pioneer a "Bring Your Own Power" (BYOP) movement. Tech giants are directly funding behind-the-meter gas generation, reviving dormant nuclear facilities, and investing in advanced cooling technologies to fuel their server farms. AI infrastructure has become such a critical priority that it is increasingly viewed through the lens of national security, prompting aggressive federal action to expand the domestic supply of key electrical grid components.\n\nOn the policy front, the US government has dramatically accelerated its embrace of artificial intelligence. Moving away from more cautious regulatory frameworks, the focus has shifted entirely to removing barriers to innovation and ensuring tech sovereignty. The goal is clear: maintain a decisive strategic edge over global competitors, particularly China. Federal AI spending has skyrocketed into the tens of billions, dominated overwhelmingly by the Department of Defense, which views AI supremacy as a non-negotiable imperative for future military readiness, cybersecurity, and global diplomacy.\n\nHowever, this hyper-accelerated growth is not without domestic friction. At the local level, the proliferation of massive data centers is creating tension in communities grappling with the environmental footprint of these facilities. Concerns over local electricity rate hikes, immense water usage in water-stressed regions, and the strain on existing utilities highlight the localized costs of a global tech race. Furthermore, while the US excels at rapid technological deployment, the corporate sector is experiencing a deep divide between companies effectively restructuring for an AI-native future and those struggling with high failure rates due to poor data quality and broken processes.\n\nIn conclusion, the United States in the age of AI represents a high-stakes, capital-fueled engine of exponential growth. It is a nation betting that its unmatched capacity for private investment, hardware innovation, and sheer ambition can overcome formidable physical bottlenecks. The American trajectory will ultimately determine whether a market-driven society can build and susta ...
#  'language_feedback': 'Strengths: The essay presents a clear, ambitious thesis about the United States as a capital- and infrastructure-driven AI epicenter. Language is vivid and reads with a strong narrative drive, effectively linking technological change to economic scale, energy infrastructure, and national security. The author uses domain-specific terms (hyperscalers, Agentic AI, Physical AI) and weaves together technology, policy, and local impacts in a coherent arc. The conclusion nicely synthesizes the argument and emphasizes high-stakes stakes and future implications. \n\nAreas for improvement: Some sentences are long and densely packed, which can hinder readability. Occasional redundancy and wordiness reduce impact (tightening would help). There are moments of assertive hyperbole that would benefit from qualifiers or evidence. Inconsistent terminology and capitalization (e.g., Agentic AI/Physical AI with inconsistent usage, BYOP vs “bring Your Own Power”) can distract readers—aim for consistency and define acronyms/terms on first use. While the piece covers macro trends, it would feel more balanced if it acknowledged uncertainties or counterpoints and, where possible, anchored claims with specific data or sources. The flow between sections can be improved with clearer signposting to guide readers through the argument.\n\nStylistic/linguistic notes: A few phrases lean toward metaphor over precision (e.g., “energy reckoning,” “capital-intensive infrastructure buildout”)—consider tightening to maintain an analytical tone. Ensure consistent hyphenation and capitalization (e.g., bring-your-own power). Consider varying sentence length to improve rhythm and emphasize key points.\n\nSuggestions for revision: 1) tighten two to three sentences per paragraph to improve readability; 2) define key terms early and maintain consistent usage throughout; 3) insert a brief counterpoint or caveat to avoid overgeneralization and bolster credibility; 4) add a concrete data point or citation for energy, spending, or policy trends to anchor assertions; 5) strengthen transitions between sections with explicit signposting (e.g., “Next, we examine policy dynamics,” “Finally, local frictions…”).',
#  'analysis_feedback': 'The essay offers a compelling big picture narrative linking AI growth to a capital-intensive infrastructure buildout, energy grid strain, and national security considerations. It introduces provocative concepts such as agentic AI and physical AI and highlights both macro trends and local frictions. However, the depth of analysis is limited by a lack of evidence, insufficient nuance, and missing alternative perspectives. Specific gaps include: no data or sources to back claims; no explicit comparison with other leading AI economies; no clear analytical framework or causal mechanisms for how AI adoption translates into economic, energy, or policy outcomes; limited treatment of risks, tradeoffs, and timelines; environmental and social impacts beyond broad mentions; minimal discussion of policy mechanisms beyond acceleration and sovereignty. The essay would benefit from a structured approach: define assumptions, present data points or scenarios, apply a framework (technological, economic, regulatory, environmental), and offer concrete policy or business implications. Adding case studies such as specific data center hubs and grid modernization efforts and addressing counterarguments would deepen the analysis. In short, strong narrative and scope but needs more evidence, explicit reasoning, and contingency analysis to reach high depth.',
#  'clarity_feedback': 'Overall clarity of thought: strong, with a clear throughline that the US is pursuing AI at scale as both infrastructure and capital development. The essay is easy to follow at a high level and combines technological, economic, and policy angles into a coherent narrative. Strengths include a solid thesis, logical progression from scale to energy constraints to policy and domestic friction, and vivid framing (e.g., BYOP, Agentic/Physical AI). \n\nKey clarity issues and opportunities for improvement:\n- Definitions and terminology: Terms like Agentic AI, Physical AI, and Bring Your Own Power are intriguing but underdefined. A brief upfront glossary or explicit definitions in the opening paragraph would improve comprehension and reduce reader guesswork.\n- Evidence and specificity: Many claims are broad (e.g., gigawatts of power, data center growth, DoD AI spending) without concrete figures or sourcing. Grounding with specific data, dates, or references would strengthen credibility and clarity of argument.\n- Logical transitions: While the overall structure is coherent, some transitions between sections are abrupt. Consider crisp topic sentences at the start of paragraphs to reinforce how each piece supports the central thesis.\n- Balance and nuance: The piece leans toward a capital-driven, techno-optimist view. Acknowledging counterarguments or potential risks (e.g., producibility, supply chain fragility, social implications) would improve argumentative balance and clarity of purpose.\n- Depth vs. breadth: The essay covers many dimensions (energy grid, policy, national security, local friction). Narrowing focus or creating a sharper sequence (e.g., scale → infrastructure constraints → policy response → societal impact) could enhance clarity and prevent the narrative from feeling diffuse.\n- Readability: Some sentences are long and dense. Breaking complex sentences into shorter ones would improve readability and maintain reader focus.\n- Policy implications: The conclusion articulates stakes but offers little on concrete policy levers or scenarios. Adding a brief set of policy options or risk-mitigated trajectories would sharpen the overall argument.\n\nOverall, the essay communicates a compelling, high-level narrative with a strong central premise. Enhancing definitions, grounding arguments in data, improving transitions, and balancing the discussion with concrete policy implications would raise clarity and persuasive impact.\n',
#  'overall_feedback': 'Here is a concise, synthesized feedback summary based on the three reviews.\n\nOverall takeaway\n- The piece presents a compelling, high-level narrative: the United States as a capital- and infrastructure-driven AI epicenter, linking technology, policy, energy, and local impacts with a strong concluding synthesis. Strengths in ambition, narrative drive, and domain-specific framing are evident.\n\nKey strengths\n- Clear, ambitious thesis and a strong throughline from scale to energy constraints to policy and local frictions.\n- Vivid framing and use of domain terms (e.g., hyperscalers, Agentic AI, Physical AI) that create a coherent arc.\n- Effective conclusion that underscores high-stakes implications.\n- Easy to follow at a high level; integrates technological, economic, and policy angles.\n\nMain areas for improvement (clustered)\n- Readability and style\n  - Long, dense sentences and some redundancy reduce impact.\n  - Occasional metaphor-heavy phrasing (e.g., “energy reckoning”) at the expense of precision.\n  - Inconsistent hyphenation and capitalization (define terms and standardize usage).\n\n- Definitions, terminology, and coherence\n  - Key terms (Agentic AI, Physical AI, Bring Your Own Power) are underdefined; define upfront or in a glossary.\n  - Terminology should be used consistently throughout.\n\n- Evidence, data, and credibility\n  - Many claims lack concrete data or sources (e.g., gigawatts, data-center growth, DoD AI spending).\n  - Need anchoring with specific data points, dates, or references to strengthen credibility.\n\n- Structure, transitions, and signposting\n  - Transitions between sections can be abrupt; improve with clear topic sentences and signposts (e.g., “Next, we examine policy dynamics.”).\n\n- balance, nuance, and credibility\n  - Leaning toward capital-driven techno-optimism; insufficient counterpoints or uncertainty.\n  - Need explicit exploration of risks, tradeoffs, timelines, and external factors (supply chain, environmental and social impacts).\n\n- depth of analysis and analytical framework\n  - Lacks explicit framework or causal mechanisms linking AI adoption to economic, energy, and policy outcomes.\n  - Missing comparative context (how the US stacks up against other AI leaders) and concrete policy or business implications.\n\n- policy implications and practicality\n  - Conclusions articulate stakes but offer few concrete policy levers or scenario-based implications.\n\nConcrete revision suggestions (actionable)\n- Tighten prose: reduce two to three sentences per paragraph to improve readability.\n- Define terms early: include a brief glossary or explicit definitions in the opening; standardize usage throughout (e.g., Agentic AI, Physical AI, bring-your-own power).\n- Ground claims in data: add specific figures, dates, and cited sources for energy, spending, capacity, and policy trends.\n- Introduce a clear analytical framework: define assumptions, present data/scenarios, apply a framework (technological, economic, regulatory, environmental), and derive policy or business implications.\n- Incorporate counterpoints: insert a brief caveat or alternative perspective to temper generalizations.\n- Improve transitions: use crisp topic sentences to connect sections and guide the reader (e.g., “Next, we examine policy dynamics,” “Finally, local frictions…”).\n- Consider scope refinement: either narrow focus to a sharper sequence (scale → infrastructure constraints → policy response → societal impact) or explicitly map the breadth with section-specific aims.\n- Add concrete policy implications: propose a short set of policy options or risk-mitigated trajectories in the conclusion.\n- Include case studies: reference specific data-center hubs, grid modernization efforts, or other concrete examples to illustrate points.\n\nIf helpful, I can draft a revised outline or a sample paragraph applying these revisions (definitions, data anchor, and signposted transitions).',
#  'individual_scores': [6, 8, 7],
#  'avg_score': 7.0}
